# %% [markdown]
# ![image.png](attachment:0d3dcd5c-f7c4-4e09-95f2-0fa5c037a57d.png)

# %% [markdown]
# ![image.png](attachment:b6078a9f-6b67-44c2-b98d-f383b3575572.png)

# %% [markdown]
# ![image.png](attachment:a6d1f9ba-ccaa-4299-820c-d96b280d2e18.png)

# %% [markdown]
# ![image.png](attachment:59f25766-8b5e-4321-8dac-ca0a47ac8ded.png)

# %%
def maximum(s, t):
    t = list(t)
    cnt = 0
    for i in s:
        if i in t:
            cnt += 1
            t.remove(i)
    return cnt




t = int(input())
for _ in range(t):
    s = input()
    t = input()

    out = maximum(s, t)
    print(out)
