# %% [markdown]
# ![image.png](attachment:1a413a10-c5dd-4a78-9354-d98bbd54a15d.png)

# %% [markdown]
# sample input 1
# ```
# 5
# 0 2 3 4 5
# ```
# sample output 1
# ```
# 0
# ```
#
# sample input 2
# ```
# 100
# -99 99 -98 98 -97 97 -96 96 -95 95 -94 94 -93 93 -92 92 -91 91 -90 90 -89 89 -88 88 -87 87 -86 86 -85 85 -84 84 -83 83 -82 82 -81 81 -80 80 -79 79 -78 78 -77 77 -76 76 -75 75 -74 74 -73 73 -72 72 -71 71 -70 70 -69 69 -68 68 -67 67 -66 66 -65 65 -64 64 -63 63 -62 62 -61 61 -60 60 -59 59 -58 58 -57 57 -56 56 -55 55 -54 54 -53 53 -52 52 -51 51 -50 50
# ```
# sample output 2
# ```
# 50
# ```
#
# sample input 3
# ```
# 100
# 99 -99 98 -98 97 -97 96 -96 95 -95 94 -94 93 -93 92 -92 91 -91 90 -90 89 -89 88 -88 87 -87 86 -86 85 -85 84 -84 83 -83 82 -82 81 -81 80 -80 79 -79 78 -78 77 -77 76 -76 75 -75 74 -74 73 -73 72 -72 71 -71 70 -70 69 -69 68 -68 67 -67 66 -66 65 -65 64 -64 63 -63 62 -62 61 -61 60 -60 59 -59 58 -58 57 -57 56 -56 55 -55 54 -54 53 -53 52 -52 51 -51 50 -50
# ```
# sample output 3
# ```
# 50
# ```

# %%
n = input()
a = [int(num) for num in input().split()]

m = abs(min(a, key=abs))
result = max([i for i in a if abs(i) == m])

print(result)

# %% [markdown]
# References
#
# - [Python - find integer closest to 0 in list](https://stackoverflow.com/questions/11923657/python-find-integer-closest-to-0-in-list)
